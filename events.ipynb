# %%
#imports
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Apple_Inc._media_events'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text,'html')

# %%
soup.find_all('span', class_='mw-headline')
# Out:
# [<span class="mw-headline" id="1984">1984</span>,
#  <span class="mw-headline" id="Macintosh_event_(January_24,_1984)">Macintosh event (January 24, 1984)</span>,
#  <span class="mw-headline" id="Macintosh_event_(Boston_Computer_Society)">Macintosh event (Boston Computer Society)</span>,
#  <span class="mw-headline" id="Apple_II_Forever_Event_(April_1984)">Apple II Forever Event (April 1984)</span>,
#  <span class="mw-headline" id="1997">1997</span>,
#  <span class="mw-headline" id="MacWorld_Expo_and_NeXT_technology_announcement">MacWorld Expo and NeXT technology announcement</span>,
#  <span class="mw-headline" id="1998">1998</span>,
#  <span class="mw-headline" id="Seybold_Seminars_New_York_1998">Seybold Seminars New York 1998</span>,
#  <span class="mw-headline" id="May_1998_Event">May 1998 Event</span>,
#  <span class="mw-headline" id="1999">1999</span>,
#  <span class="mw-headline" id="Macworld_SanFrancisco_(January_5,_1999)">Macworld SanFrancisco (January 5, 1999)</span>,
#  <span class="mw-headline" id="WWDC_(May_1999)">WWDC (May 1999)</span>,
#  <span class="mw-headline" id="Macworld_Expo_NY_'99_(July_21,_1999)">Macworld Expo NY '99 (July 21, 1999)</span>,
#  <span class="mw-headline" id="Seybold_1999">Seybold 1999</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_5,_1999)">Apple special event (October 5, 1999)</span>,
#  <span class="mw-headline" id="2000">2000</span>,
#  <span class="mw-headline" id="Macworld_2000_(San_Francisco)">Macworld 2000 (San Francisco)</span>,
#  <span class="mw-headline" id="Macworld_Expo,_New_York_(July_19,_2000)">Macworld Expo, New York (July 19, 2000)</span>,
#  <span class="mw-headline" id="2001">2001</span>,
#  <span class="mw-headline" id="Macworld_2001_(San_Francisco)">Macworld 2001 (San Francisco)</span>,
#  <span class="mw-headline" id="2002">2002</span>,
#  <span class="mw-headline" id="Macworld_2002_San_Francisco_(January_7,_2002)">Macworld 2002 San Francisco (January 7, 2002)</span>,
#  <span class="mw-headline" id="Macworld_2002_New_York_(July_17,_2002)">Macworld 2002 New York (July 17, 2002)</span>,
#  <span class="mw-headline" id="Apple_Expo_2002,_Paris_(September_10,_2002)">Apple Expo 2002, Paris (September 10, 2002)</span>,
#  <span class="mw-headline" id="2003">2003</span>,
#  <span class="mw-headline" id="Macworld_2003_San_Francisco_(January_20,_2003)">Macworld 2003 San Francisco (January 20, 2003)</span>,
#  <span class="mw-headline" id="WWDC_2003_(June_23,_2003)">WWDC 2003 (June 23, 2003)</span>,
#  <span class="mw-headline" id="Apple_Expo_Paris_2003_(September_16,_2003)">Apple Expo Paris 2003 (September 16, 2003)</span>,
#  <span class="mw-headline" id="2004">2004</span>,
#  <span class="mw-headline" id="Macworld_2004">Macworld 2004</span>,
#  <span class="mw-headline" id="Music_Event_London_(June_15,_2004)">Music Event London (June 15, 2004)</span>,
#  <span class="mw-headline" id="WWDC_2004_(June_28,_2004)">WWDC 2004 (June 28, 2004)</span>,
#  <span class="mw-headline" id="Music_Event_(October_26,_2004)">Music Event (October 26, 2004)</span>,
#  <span class="mw-headline" id="2005">2005</span>,
#  <span class="mw-headline" id="Macworld_2005_(January_2005,_San_Francisco)">Macworld 2005 (January 2005, San Francisco)</span>,
#  <span class="mw-headline" id="WWDC_2005_(June_6–10,_2005)">WWDC 2005 (June 6–10, 2005)</span>,
#  <span class="mw-headline" id="Apple_music_event_(September_7,_2005)">Apple music event (September 7, 2005)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_2005)">Apple special event (October 2005)</span>,
#  <span class="mw-headline" id="2006">2006</span>,
#  <span class="mw-headline" id="Macworld_2006_(January_10,_2006)">Macworld 2006 (January 10, 2006)</span>,
#  <span class="mw-headline" id="Apple_special_event_(February_28,_2006)">Apple special event (February 28, 2006)</span>,
#  <span class="mw-headline" id="WWDC_2006_(August_7–11,_2006)">WWDC 2006 (August 7–11, 2006)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_12,_2006)">Apple special event (September 12, 2006)</span>,
#  <span class="mw-headline" id="2007">2007</span>,
#  <span class="mw-headline" id="Macworld_Conference_&amp;_Expo_San_Francisco_2007_(Tuesday,_January_9,_2007)">Macworld Conference &amp; Expo San Francisco 2007 (Tuesday, January 9, 2007)</span>,
#  <span class="mw-headline" id="WWDC_2007_(June_11–15,_2007)">WWDC 2007 (June 11–15, 2007)</span>,
#  <span class="mw-headline" id="Special_Event_2007_(August_7,_2007)">Special Event 2007 (August 7, 2007)</span>,
#  <span class="mw-headline" id="Apple_music_event_2007_(September_5,_2007)">Apple music event 2007 (September 5, 2007)</span>,
#  <span class="mw-headline" id="2008">2008</span>,
#  <span class="mw-headline" id="Macworld_Conference_&amp;_Expo_San_Francisco_2008_(Wednesday,_January_16,_2008)">Macworld Conference &amp; Expo San Francisco 2008 (Wednesday, January 16, 2008)</span>,
#  <span class="mw-headline" id="iPhone_Software_Roadmap_Event_(March_6,_2008)">iPhone Software Roadmap Event (March 6, 2008)</span>,
#  <span class="mw-headline" id="WWDC_2008_(June_9–13,_2008)">WWDC 2008 (June 9–13, 2008)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_9,_2008)">Apple special event (September 9, 2008)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_14,_2008)">Apple special event (October 14, 2008)</span>,
#  <span class="mw-headline" id="2009">2009</span>,
#  <span class="mw-headline" id="Macworld_SF_2009">Macworld SF 2009</span>,
#  <span class="mw-headline" id="WWDC_2009_(June_8–12,_2009)">WWDC 2009 (June 8–12, 2009)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_9,_2009)">Apple special event (September 9, 2009)</span>,
#  <span class="mw-headline" id="2010">2010</span>,
#  <span class="mw-headline" id="Apple_special_event_(January_27,_2010)">Apple special event (January 27, 2010)</span>,
#  <span class="mw-headline" id="Apple_special_event_(April_8,_2010)">Apple special event (April 8, 2010)</span>,
#  <span class="mw-headline" id="WWDC_2010_(June_7–11,_2010)">WWDC 2010 (June 7–11, 2010)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_1,_2010)">Apple special event (September 1, 2010)</span>,
#  <span class="mw-headline" id="Apple's_'Back_to_the_Mac'_event_(October_20,_2010)">Apple's 'Back to the Mac' event (October 20, 2010)</span>,
#  <span class="mw-headline" id="2011">2011</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_2,_2011)">Apple special event (March 2, 2011)</span>,
#  <span class="mw-headline" id="WWDC_2011_(June_6–10,_2011)">WWDC 2011 (June 6–10, 2011)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_4,_2011)">Apple special event (October 4, 2011)</span>,
#  <span class="mw-headline" id="2012">2012</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_7,_2012)">Apple special event (March 7, 2012)</span>,
#  <span class="mw-headline" id="WWDC_2012_(June_11–15,_2012)">WWDC 2012 (June 11–15, 2012)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_12,_2012)">Apple special event (September 12, 2012)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_23,_2012)">Apple special event (October 23, 2012)</span>,
#  <span class="mw-headline" id="2013">2013</span>,
#  <span class="mw-headline" id="WWDC_2013_(June_10–14,_2013)">WWDC 2013 (June 10–14, 2013)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_10,_2013)">Apple special event (September 10, 2013)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_22,_2013)">Apple special event (October 22, 2013)</span>,
#  <span class="mw-headline" id="2014">2014</span>,
#  <span class="mw-headline" id="WWDC_2014_(June_2–6,_2014)">WWDC 2014 (June 2–6, 2014)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_9,_2014)">Apple special event (September 9, 2014)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_16,_2014)">Apple special event (October 16, 2014)</span>,
#  <span class="mw-headline" id="2015">2015</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_9,_2015)">Apple special event (March 9, 2015)</span>,
#  <span class="mw-headline" id="WWDC_2015_(June_8–12,_2015)">WWDC 2015 (June 8–12, 2015)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_9,_2015)">Apple special event (September 9, 2015)</span>,
#  <span class="mw-headline" id="2016">2016</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_21,_2016)">Apple special event (March 21, 2016)</span>,
#  <span class="mw-headline" id="WWDC_2016_(June_13–17,_2016)">WWDC 2016 (June 13–17, 2016)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_7,_2016)">Apple special event (September 7, 2016)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_27,_2016)">Apple special event (October 27, 2016)</span>,
#  <span class="mw-headline" id="2017">2017</span>,
#  <span class="mw-headline" id="WWDC_2017_(June_5–9,_2017)">WWDC 2017 (June 5–9, 2017)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_12,_2017)">Apple special event (September 12, 2017)</span>,
#  <span class="mw-headline" id="2018">2018</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_27,_2018)">Apple special event (March 27, 2018)</span>,
#  <span class="mw-headline" id="WWDC_2018_(June_4–8,_2018)">WWDC 2018 (June 4–8, 2018)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_12,_2018)">Apple special event (September 12, 2018)</span>,
#  <span class="mw-headline" id="Apple_special_event_(October_30,_2018)">Apple special event (October 30, 2018)</span>,
#  <span class="mw-headline" id="2019">2019</span>,
#  <span class="mw-headline" id="Apple_special_event_(March_25,_2019)">Apple special event (March 25, 2019)</span>,
#  <span class="mw-headline" id="WWDC_2019_(June_3–7,_2019)">WWDC 2019 (June 3–7, 2019)</span>,
#  <span class="mw-headline" id="Apple_special_event_(September_10,_2019)">Apple special event (September 10, 2019)</span>,
#  <span class="mw-headline" id="2020">2020</span>,
#  <span class="mw-headline" id="WWDC_2020_(June_22–26,_2020)">WWDC 2020 (June 22–26, 2020)</span>,
#  <span class="mw-headline" id="Apple_event_(September_15,_2020)">Apple event (September 15, 2020)</span>,
#  <span class="mw-headline" id="Apple_event_(October_13,_2020)">Apple event (October 13, 2020)</span>,
#  <span class="mw-headline" id="Apple_event_(November_10,_2020)">Apple event (November 10, 2020)</span>,
#  <span class="mw-headline" id="2021">2021</span>,
#  <span class="mw-headline" id="Apple_event_(April_20,_2021)">Apple event (April 20, 2021)</span>,
#  <span class="mw-headline" id="WWDC_2021_(June_7–11,_2021)">WWDC 2021 (June 7–11, 2021)</span>,
#  <span class="mw-headline" id="Apple_event_(September_14,_2021)">Apple event (September 14, 2021)</span>,
#  <span class="mw-headline" id="Apple_event_(October_18,_2021)">Apple event (October 18, 2021)</span>,
#  <span class="mw-headline" id="2022">2022</span>,
#  <span class="mw-headline" id="Apple_event_(March_8,_2022)">Apple event (March 8, 2022)</span>,
#  <span class="mw-headline" id="WWDC_2022_(June_6–10,_2022)">WWDC 2022 (June 6–10, 2022)</span>,
#  <span class="mw-headline" id="Apple_event_(September_7,_2022)">Apple event (September 7, 2022)</span>,
#  <span class="mw-headline" id="2023">2023</span>,
#  <span class="mw-headline" id="WWDC_2023_(June_5–9,_2023)">WWDC 2023 (June 5–9, 2023)</span>,
#  <span class="mw-headline" id="Apple_event_(September_12,_2023)">Apple event (September 12, 2023)</span>,
#  <span class="mw-headline" id="Apple_event_(October_30,_2023)">Apple event (October 30, 2023)</span>,
#  <span class="mw-headline" id="2024">2024</span>,
#  <span class="mw-headline" id="Apple_event_(May_7,_2024)">Apple event (May 7, 2024)</span>,
#  <span class="mw-headline" id="WWDC_2024_(June_10–14,_2024)">WWDC 2024 (June 10–14, 2024)</span>,
#  <span class="mw-headline" id="See_also">See also</span>,
#  <span class="mw-headline" id="References">References</span>]

# %%
import re

# Assuming `soup` is your BeautifulSoup object containing the parsed HTML

events_data = []
current_year = ""

def extract_date(event_name, current_year):
    # Regular expression patterns
    full_date_pattern = r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{1,2},\s\d{4}\b'
    month_year_pattern = r'\b(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}\b'
    date_range_pattern = r'\b\d{1,2}–\d{1,2}\b'
    
    # Try to extract the full date (e.g., January 24, 1984)
    full_date_match = re.search(full_date_pattern, event_name)
    if full_date_match:
        return full_date_match.group(0)
    
    # Try to extract a month and year (e.g., January 1984), assuming the current year
    month_year_match = re.search(month_year_pattern, event_name)
    if month_year_match:
        # Check for date range within the same month (e.g., 5–9)
        date_range_match = re.search(date_range_pattern, event_name)
        if date_range_match:
            # Extract start and end dates
            start_date, end_date = date_range_match.group(0).split("–")
            return f"{month_year_match.group(0)} from {start_date} to {end_date}"
        return month_year_match.group(0)
    
    # If the event name contains no recognizable date, return the year or null
    return current_year if current_year else "NULL"

for span in soup.find_all('span', class_='mw-headline'):
    if span['id'].isdigit() and len(span['id']) == 4:
        current_year = span['id']
    else:
        event_name = span.text
        if event_name == 'See also' or event_name == 'References':
            continue
        date = extract_date(event_name, current_year)
        print(event_name)
        print(date)
        events_data.append([date, event_name])
# Out:
# Macintosh event (January 24, 1984)
# January 24, 1984
# Macintosh event (Boston Computer Society)
# 1984
# Apple II Forever Event (April 1984)
# April 1984
# MacWorld Expo and NeXT technology announcement
# 1997
# Seybold Seminars New York 1998
# 1998
# May 1998 Event
# May 1998
# Macworld SanFrancisco (January 5, 1999)
# January 5, 1999
# WWDC (May 1999)
# May 1999
# Macworld Expo NY '99 (July 21, 1999)
# July 21, 1999
# Seybold 1999
# 1999
# Apple special event (October 5, 1999)
# October 5, 1999
# Macworld 2000 (San Francisco)
# 2000
# Macworld Expo, New York (July 19, 2000)
# July 19, 2000
# Macworld 2001 (San Francisco)
# 2001
# Macworld 2002 San Francisco (January 7, 2002)
# January 7, 2002
# Macworld 2002 New York (July 17, 2002)
# July 17, 2002
# Apple Expo 2002, Paris (September 10, 2002)
# September 10, 2002
# Macworld 2003 San Francisco (January 20, 2003)
# January 20, 2003
# WWDC 2003 (June 23, 2003)
# June 23, 2003
# Apple Expo Paris 2003 (September 16, 2003)
# September 16, 2003
# Macworld 2004
# 2004
# Music Event London (June 15, 2004)
# June 15, 2004
# WWDC 2004 (June 28, 2004)
# June 28, 2004
# Music Event (October 26, 2004)
# October 26, 2004
# Macworld 2005 (January 2005, San Francisco)
# January 2005
# WWDC 2005 (June 6–10, 2005)
# 2005
# Apple music event (September 7, 2005)
# September 7, 2005
# Apple special event (October 2005)
# October 2005
# Macworld 2006 (January 10, 2006)
# January 10, 2006
# Apple special event (February 28, 2006)
# February 28, 2006
# WWDC 2006 (August 7–11, 2006)
# 2006
# Apple special event (September 12, 2006)
# September 12, 2006
# Macworld Conference & Expo San Francisco 2007 (Tuesday, January 9, 2007)
# January 9, 2007
# WWDC 2007 (June 11–15, 2007)
# 2007
# Special Event 2007 (August 7, 2007)
# August 7, 2007
# Apple music event 2007 (September 5, 2007)
# September 5, 2007
# Macworld Conference & Expo San Francisco 2008 (Wednesday, January 16, 2008)
# January 16, 2008
# iPhone Software Roadmap Event (March 6, 2008)
# March 6, 2008
# WWDC 2008 (June 9–13, 2008)
# 2008
# Apple special event (September 9, 2008)
# September 9, 2008
# Apple special event (October 14, 2008)
# October 14, 2008
# Macworld SF 2009
# 2009
# WWDC 2009 (June 8–12, 2009)
# 2009
# Apple special event (September 9, 2009)
# September 9, 2009
# Apple special event (January 27, 2010)
# January 27, 2010
# Apple special event (April 8, 2010)
# April 8, 2010
# WWDC 2010 (June 7–11, 2010)
# 2010
# Apple special event (September 1, 2010)
# September 1, 2010
# Apple's 'Back to the Mac' event (October 20, 2010)
# October 20, 2010
# Apple special event (March 2, 2011)
# March 2, 2011
# WWDC 2011 (June 6–10, 2011)
# 2011
# Apple special event (October 4, 2011)
# October 4, 2011
# Apple special event (March 7, 2012)
# March 7, 2012
# WWDC 2012 (June 11–15, 2012)
# 2012
# Apple special event (September 12, 2012)
# September 12, 2012
# Apple special event (October 23, 2012)
# October 23, 2012
# WWDC 2013 (June 10–14, 2013)
# 2013
# Apple special event (September 10, 2013)
# September 10, 2013
# Apple special event (October 22, 2013)
# October 22, 2013
# WWDC 2014 (June 2–6, 2014)
# 2014
# Apple special event (September 9, 2014)
# September 9, 2014
# Apple special event (October 16, 2014)
# October 16, 2014
# Apple special event (March 9, 2015)
# March 9, 2015
# WWDC 2015 (June 8–12, 2015)
# 2015
# Apple special event (September 9, 2015)
# September 9, 2015
# Apple special event (March 21, 2016)
# March 21, 2016
# WWDC 2016 (June 13–17, 2016)
# 2016
# Apple special event (September 7, 2016)
# September 7, 2016
# Apple special event (October 27, 2016)
# October 27, 2016
# WWDC 2017 (June 5–9, 2017)
# 2017
# Apple special event (September 12, 2017)
# September 12, 2017
# Apple special event (March 27, 2018)
# March 27, 2018
# WWDC 2018 (June 4–8, 2018)
# 2018
# Apple special event (September 12, 2018)
# September 12, 2018
# Apple special event (October 30, 2018)
# October 30, 2018
# Apple special event (March 25, 2019)
# March 25, 2019
# WWDC 2019 (June 3–7, 2019)
# 2019
# Apple special event (September 10, 2019)
# September 10, 2019
# WWDC 2020 (June 22–26, 2020)
# 2020
# Apple event (September 15, 2020)
# September 15, 2020
# Apple event (October 13, 2020)
# October 13, 2020
# Apple event (November 10, 2020)
# November 10, 2020
# Apple event (April 20, 2021)
# April 20, 2021
# WWDC 2021 (June 7–11, 2021)
# 2021
# Apple event (September 14, 2021)
# September 14, 2021
# Apple event (October 18, 2021)
# October 18, 2021
# Apple event (March 8, 2022)
# March 8, 2022
# WWDC 2022 (June 6–10, 2022)
# 2022
# Apple event (September 7, 2022)
# September 7, 2022
# WWDC 2023 (June 5–9, 2023)
# 2023
# Apple event (September 12, 2023)
# September 12, 2023
# Apple event (October 30, 2023)
# October 30, 2023
# Apple event (May 7, 2024)
# May 7, 2024
# WWDC 2024 (June 10–14, 2024)
# 2024

# %%
print(events_data)
# Out:
# [['January 24, 1984', 'Macintosh event (January 24, 1984)'], ['1984', 'Macintosh event (Boston Computer Society)'], ['April 1984', 'Apple II Forever Event (April 1984)'], ['1997', 'MacWorld Expo and NeXT technology announcement'], ['1998', 'Seybold Seminars New York 1998'], ['May 1998', 'May 1998 Event'], ['January 5, 1999', 'Macworld SanFrancisco (January 5, 1999)'], ['May 1999', 'WWDC (May 1999)'], ['July 21, 1999', "Macworld Expo NY '99 (July 21, 1999)"], ['1999', 'Seybold 1999'], ['October 5, 1999', 'Apple special event (October 5, 1999)'], ['2000', 'Macworld 2000 (San Francisco)'], ['July 19, 2000', 'Macworld Expo, New York (July 19, 2000)'], ['2001', 'Macworld 2001 (San Francisco)'], ['January 7, 2002', 'Macworld 2002 San Francisco (January 7, 2002)'], ['July 17, 2002', 'Macworld 2002 New York (July 17, 2002)'], ['September 10, 2002', 'Apple Expo 2002, Paris (September 10, 2002)'], ['January 20, 2003', 'Macworld 2003 San Francisco (January 20, 2003)'], ['June 23, 2003', 'WWDC 2003 (June 23, 2003)'], ['September 16, 2003', 'Apple Expo Paris 2003 (September 16, 2003)'], ['2004', 'Macworld 2004'], ['June 15, 2004', 'Music Event London (June 15, 2004)'], ['June 28, 2004', 'WWDC 2004 (June 28, 2004)'], ['October 26, 2004', 'Music Event (October 26, 2004)'], ['January 2005', 'Macworld 2005 (January 2005, San Francisco)'], ['2005', 'WWDC 2005 (June 6–10, 2005)'], ['September 7, 2005', 'Apple music event (September 7, 2005)'], ['October 2005', 'Apple special event (October 2005)'], ['January 10, 2006', 'Macworld 2006 (January 10, 2006)'], ['February 28, 2006', 'Apple special event (February 28, 2006)'], ['2006', 'WWDC 2006 (August 7–11, 2006)'], ['September 12, 2006', 'Apple special event (September 12, 2006)'], ['January 9, 2007', 'Macworld Conference & Expo San Francisco 2007 (Tuesday, January 9, 2007)'], ['2007', 'WWDC 2007 (June 11–15, 2007)'], ['August 7, 2007', 'Special Event 2007 (August 7, 2007)'], ['September 5, 2007', 'Apple music event 2007 (September 5, 2007)'], ['January 16, 2008', 'Macworld Conference & Expo San Francisco 2008 (Wednesday, January 16, 2008)'], ['March 6, 2008', 'iPhone Software Roadmap Event (March 6, 2008)'], ['2008', 'WWDC 2008 (June 9–13, 2008)'], ['September 9, 2008', 'Apple special event (September 9, 2008)'], ['October 14, 2008', 'Apple special event (October 14, 2008)'], ['2009', 'Macworld SF 2009'], ['2009', 'WWDC 2009 (June 8–12, 2009)'], ['September 9, 2009', 'Apple special event (September 9, 2009)'], ['January 27, 2010', 'Apple special event (January 27, 2010)'], ['April 8, 2010', 'Apple special event (April 8, 2010)'], ['2010', 'WWDC 2010 (June 7–11, 2010)'], ['September 1, 2010', 'Apple special event (September 1, 2010)'], ['October 20, 2010', "Apple's 'Back to the Mac' event (October 20, 2010)"], ['March 2, 2011', 'Apple special event (March 2, 2011)'], ['2011', 'WWDC 2011 (June 6–10, 2011)'], ['October 4, 2011', 'Apple special event (October 4, 2011)'], ['March 7, 2012', 'Apple special event (March 7, 2012)'], ['2012', 'WWDC 2012 (June 11–15, 2012)'], ['September 12, 2012', 'Apple special event (September 12, 2012)'], ['October 23, 2012', 'Apple special event (October 23, 2012)'], ['2013', 'WWDC 2013 (June 10–14, 2013)'], ['September 10, 2013', 'Apple special event (September 10, 2013)'], ['October 22, 2013', 'Apple special event (October 22, 2013)'], ['2014', 'WWDC 2014 (June 2–6, 2014)'], ['September 9, 2014', 'Apple special event (September 9, 2014)'], ['October 16, 2014', 'Apple special event (October 16, 2014)'], ['March 9, 2015', 'Apple special event (March 9, 2015)'], ['2015', 'WWDC 2015 (June 8–12, 2015)'], ['September 9, 2015', 'Apple special event (September 9, 2015)'], ['March 21, 2016', 'Apple special event (March 21, 2016)'], ['2016', 'WWDC 2016 (June 13–17, 2016)'], ['September 7, 2016', 'Apple special event (September 7, 2016)'], ['October 27, 2016', 'Apple special event (October 27, 2016)'], ['2017', 'WWDC 2017 (June 5–9, 2017)'], ['September 12, 2017', 'Apple special ...

# %%
import csv
# Write the data to a CSV file
csv_file_path = "apple_events.csv"
with open(csv_file_path, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Date", "Event Name"])  # Update the header to include Date instead of Year
    writer.writerows(events_data)
